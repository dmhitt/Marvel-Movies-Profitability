# %%
import numpy as np
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt
from pprint import pprint

from config import api_key

url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + api_key
    
# Make request and store response
response = requests.get(url + api_key)

# Reading in the CSV's
marvel_movies_df= pd.read_csv('mcu_domestic_global_box_office_fixed_endgame.csv')
iron_vs_cap_df= pd.read_csv('rdj ce movie data.csv')

all_movie_data = []

# Print status code
# print(response)
#marvel_movies_df
#iron_vs_cap_df

# %%
response = requests.get(url + "Iron Man" + api_key)
iron_man_data = response.json()

all_movie_data.append(iron_man_data)
#pprint(iron_man_data)

response = requests.get(url + "The Incredible Hulk" + api_key)
incredible_hulk_data = response.json()

all_movie_data.append(incredible_hulk_data)
#pprint(incredible_hulk_data)

response = requests.get(url + "Iron Man 2" + api_key)
iron_man_2_data = response.json()

all_movie_data.append(iron_man_2_data)
#pprint(iron_man_2_data)

response = requests.get(url + "Thor" + api_key)
thor_data = response.json()

all_movie_data.append(thor_data)
#pprint(thor_data)

response = requests.get(url + "Captain America: The First Avenger" + api_key)
captain_america_data = response.json()

all_movie_data.append(captain_america_data)
#pprint(captain_america_data)

response = requests.get(url + "Avengers" + api_key)
avengers_data = response.json()

all_movie_data.append(avengers_data)
#pprint(avengers_data)

response = requests.get(url + "Iron Man 3" + api_key)
iron_man_3_data = response.json()

all_movie_data.append(iron_man_3_data)
#pprint(iron_man_3_data)

response = requests.get(url + "Thor: The Dark World" + api_key)
thor_dark_world_data = response.json()

all_movie_data.append(thor_dark_world_data)
#pprint(thor_dark_world_data)

response = requests.get(url + "Captain America: The Winter Soldier" + api_key)
captain_america_winter_soldier_data = response.json()

all_movie_data.append(captain_america_winter_soldier_data)
#pprint(captain_america_winter_soldier_data)

response = requests.get(url + "Guardians of the Galaxy" + api_key)
guardians_galaxy_data = response.json()

all_movie_data.append(guardians_galaxy_data)
#pprint(guardians_galaxy_data)

response = requests.get(url + "Avengers: Age of Ultron" + api_key)
avengers_ultron_data = response.json()

all_movie_data.append(avengers_ultron_data)
#pprint(avengers_ultron_data)

response = requests.get(url + "Ant-Man" + api_key)
ant_man_data = response.json()

all_movie_data.append(ant_man_data)
#pprint(ant_man_data)

response = requests.get(url + "Captain America: Civil War" + api_key)
captain_america_civil_war = response.json()

all_movie_data.append(captain_america_civil_war)
#pprint(captain_america_civil_war)

response = requests.get(url + "Doctor Strange" + api_key)
doctor_strange_data = response.json()

all_movie_data.append(doctor_strange_data)
#pprint(doctor_strange_data)

response = requests.get(url + "Guardians of the Galaxy Vol 2" + api_key)
guardians_galaxy_2_data = response.json()

all_movie_data.append(guardians_galaxy_2_data)
#pprint(guardians_galaxy_2_data)

response = requests.get(url + "Spider-Man: Homecoming" + api_key)
spider_man_homecoming_data = response.json()

all_movie_data.append(spider_man_homecoming_data)
#pprint(spider_man_homecoming_data)

response = requests.get(url + "Thor: Ragnarok" + api_key)
thor_ragnarok_data = response.json()

all_movie_data.append(thor_ragnarok_data)
#pprint(thor_ragnarok_data)

response = requests.get(url + "Black Panther" + api_key)
black_panther_data = response.json()

all_movie_data.append(black_panther_data)
#pprint(black_panther_data)

response = requests.get(url + "Avengers: Infinity War" + api_key)
avengers_infinity_war_data = response.json()

all_movie_data.append(avengers_infinity_war_data)
#pprint(avengers_infinity_war_data)

response = requests.get(url + "Ant-Man and the Wasp" + api_key)
ant_man_wasp_data = response.json()

all_movie_data.append(ant_man_wasp_data)
#pprint(ant_man_wasp_data)

response = requests.get(url + "Captain Marvel" + api_key)
captain_marvel_data = response.json()

all_movie_data.append(captain_marvel_data)
#pprint(captain_marvel_data)

response = requests.get(url + "Avengers: Endgame" + api_key)
avengers_endgame_data = response.json()

all_movie_data.append(avengers_endgame_data)
#pprint(avengers_endgame_data)

# %%
#captain_america_winter_soldier_data["BoxOffice"]
#all_movie_data

# %%
plt.bar(marvel_movies_df['Title'], marvel_movies_df['Domestic box office'], color="b", align="center")
# Out:
# <BarContainer object of 22 artists>
