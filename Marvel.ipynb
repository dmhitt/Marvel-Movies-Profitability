# %%
#import dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st 
from scipy.stats import linregress
import numpy as np 

#csv files
file_1 = pd.read_csv("Resources/imdb_com-free_deduped_n_merged_20190717_110503667764395.csv")
file_2 = pd.read_csv("mcu_domestic_global_box_office-2.csv")

#merge the csv files 
marvel = pd.merge(file_1, file_2, on = "Title", how = "right") 
marvel
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-40b16455095f> in <module>
#       7
#       8 #csv files
# ----> 9 file_1 = pd.read_csv("Resources/imdb_com-free_deduped_n_merged_20190717_110503667764395.csv")
#      10 file_2 = pd.read_csv("mcu_domestic_global_box_office-2.csv")
#      11
#
# ...
